# %%
import sys # This imports the sys module, which provides access to some variables used or maintained by the interpreter and to functions that interact strongly with the interpreter.
print(sys.executable) # This prints the path of the Python interpreter.
# Out:
# c:\Users\bhavi\chat_bot\.venv\Scripts\python.exe

# %%
from dotenv import load_dotenv # This loads environment variables from a .env file into the environment.
load_dotenv(override=True)# this overrides any existing environment variables with the ones in the .env file.
# Out:
# True

# %%
import os# This imports the os module, which provides a way of using operating system dependent functionality like reading or writing to the file system.
print(os.getcwd())  # This prints the current working directory.
openai=os.getenv("OPENAI_API_KEY") # This gets the value of the OPENAI_API_KEY environment variable.
# Out:
# c:\Users\bhavi\chat_bot

# %%
from openai import OpenAI # This imports the OpenAI class from the openai module.

# This checks if the openai variable is set and prints a message if it is.
if openai:
    print(f" API Key exists and begins {openai[:8]}")
else:
    print("openai API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
#  API Key exists and begins sk-proj-

# %%
import os
openai = OpenAI() # This creates an OpenAI client object to talk to GPT models, embeddings, images, etc.

# %%
# Create a list holding our conversation. We start with a single user message asking a simple question
#role is the role of the message.
#content is the content of the message.
#role:user tells that the message is from the user.

messages = [{"role": "user", "content": "What is 2+2?"}] # This creates a list of messages, each with a role and content.

# Ask the AI model to process our message and generate an answer.
# (We pass in our message list and specify which AI model we want to handle the job.)

response = openai.chat.completions.create(  
    messages=messages # this is the list of messages to be used for the chat completion.
)

#choise is a list of choices, each with a message and index.
#choices[0] is the first choice in the list.
#message is the message in the choice.
#content is the content of the message.

# Pull the actual text answer out of the AI's reply structure and print it to the screen.
print(response.choices[0].message.content)
# Out:
# 2 + 2 equals 4.

# %% [markdown]
# with gemini

# %%
import os
google_api_key=os.getenv("google_api_key") # google_api_key is name of key in .env file
openai=os.getenv("openai")#getenv is used to get the value of the environment variable.

# %%
google_api_key = os.getenv('google_api_key') # google_api_key is name of key in .env file

if google_api_key:
    print(f"google API Key exists and begins {google_api_key[:8]}")
else:
    print("google API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# google API Key exists and begins AQ.Ab8RN

# %%
from dotenv import load_dotenv # dotenv is the module that loads environment variables from a .env file into the environment.
from openai import OpenAI #OpenAI is used to create an OpenAI client object to talk to GPT models, embeddings, images, etc.
import os #os is used to get the value of the environment variable.
from IPython.display import Markdown # Ipython.display is a modul provide api for rich media display tool.  Markdown is used to display the markdown text. 

load_dotenv(override=True) #this overrides any existing environment variables with the ones in the .env file.

# It allows you to run Google's Gemini models using the official openai Python SDK instead of needing the Google Generative AI SDK.  
client = OpenAI(
    api_key=os.getenv("GOOGLE_API_KEY"),
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %% [markdown]
# if you find any error in response then first check your model

# %%
# Create a list holding our conversation. We start with a single user message asking a simple question
messages = [{"role": "user", "content": "What is 2+2?"}]

# Ask the AI model to process our message and generate an answer.
# (We pass in our message list and specify which AI model we want to handle the job.)

response = client.chat.completions.create(
    model="gemini-3.6-flash",
    messages=messages
)

# Pull the actual text answer out of the AI's reply structure and print it to the screen.
print(response.choices[0].message.content)
# Out:
# 2 + 2 = 4

# %%
# And now - let's ask for a question:

# Store the text prompt as a string; this will serve as the content inside our message payload.
question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."

# Wrap the prompt string in the list-and-dictionary structure that the OpenAI client expects.
messages = [{"role": "user", "content": question}]

response = client.chat.completions.create(
    model="gemini-3.5-flash",
    messages=messages
)

# Extract and print the generated IQ question from the AI's response
print(response.choices[0].message.content)



##VVIMP: Here prompt to gemini model is question variable.
# Out:
# Three logicians, A, B, and C, each wear a hat with a positive integer written on it. They are told that one of the numbers is the sum of the other two. Each logician can see the other two numbers but not their own.
#
# The master asks them in order:
# A: "Do you know your number?" A replies: "No."
# B: "Do you know your number?" B replies: "No."
# C: "Do you know your number?" C replies: "No."
# A is asked again: "Do you know your number now?" A replies: "Yes, it is 144."
#
# What are the numbers on B and C's hats?

# %%
# Grab the text response from the previous step and store it as our new prompt.
question = response.choices[0].message.content

# Format the prompt into the message list required by the OpenAI client.
messages = [{"role": "user", "content": question}]

# Send the new prompt back to the Gemini model for a response.
response = client.chat.completions.create(
    model="gemini-3.5-flash",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# To find the numbers on B and C's hats, we can analyze the deductions made by each logician at each step.
#
# Let the positive integers on the hats of A, B, and C be $a$, $b$, and $c$, respectively. We are given that one of the numbers is the sum of the other two. Since $a, b, c > 0$, the largest number must be the sum of the other two.
#
# At each turn, a logician can deduce their own number only if one of their two possible options (the sum or the absolute difference of the other two) is ruled out. Since there is no upper limit on the integers, a sum $x+y$ can never be ruled out, whereas a difference $|x-y|$ can be ruled out if it is non-positive (which happens if $x=y$) or if it contradicts a previous deduction. Thus, the first person to say "Yes" must have the sum of the other two numbers.
#
# Since A says "Yes" in the second round, A's number must be the sum of B and C's numbers:
# $$a = b + c = 144$$
#
# Let's analyze what we learn from each logician saying "No":
#
# ### Round 1:
# 1. **A says "No":**
#    A sees $b$ and $c$. If $b = c$, A's difference would be $0$, which is impossible. Thus, A would have known $a = b+c$. Since A said "No":
#    * $b \neq c$
#
# 2. **B says "No":**
#    B sees $a$ and $c$. B knows $b = a+c$ or $b = |a-c|$. B would say "Yes" if:
#    * $a = c$ (as the difference is 0)
#    * $b = |a-c|$ is ruled out because it would have forced A to say "Yes" in step 1 (i.e., $|a-c| = c \implies a = 2c$).
#    Since B said "No":
#    * $a \neq c$
#    * $a \neq 2c$
#
# 3. **C says "No":**
#    C sees $a$ and $b$. C knows $c = a+b$ or $c = |a-b|$. C would say "Yes" if:
#    * $a = b$ (difference is 0)
#    * $c = |a-b|$ is ruled out by A1 or B1. This happens if:
#      * $|a-b| = b \implies a = 2b$
#      * $a = |a-b| \implies b = 2a$
#      * $a = 2|a-b| \implies 2b = 3a$ (since $b > a$)
#    Since C said "No":
#    * $a \neq b$
#    * $a \neq 2b$
#    * $b \neq 2a$
#    * $2b \neq 3a$
#
# ---
#
# ### Round 2:
# 4. **A says "Yes, it is 144":**
#    A knows $a = b+c = 144$. For A to know this, A's alternative $a = |b-c|$ must have been ruled out by the previous "No" answers of B and C.
#
#    Thus, the hypothetical triple $(|b-c|, b, c)$ must violate one of the conditions established in B1 or C1:
#
#    * **Case 1: Violating B1's conditions**
#      * **Subcase 1a:** $|b-c| = c \implies b = 2c$
#        Since $a = b+c = 144$, we get $2c+c = 144 \implies 3c = 144 \implies c = 48$.
#        This gives **$b = 96, c = 48$**.
#      * **Subcase 1b:** $|b-c| = 2c \implies b = 3c$
#        Since $a = b+c = 144$, we get $3c+c = 144 \implies 4c = 144 \implies c = 36$.
#        This gives **$b = 108, c = 36$**.
#
#    * **Case 2: Violating C1's conditions**
#      * **Subcase 2a:** $|b-c| = b \implies c = 2b$
#        Since $a = b+c = 144$, we get $b+2b = 144 \implies 3b = 144 \implies b = 48$.
#        This gives **$b = 48, c = 96$**.
#      * **Subcase 2b:** $|b-c| = 2b \implies c = 3b$
#        Since $a = b+c = 144$, we get $b+3b = 144 \implies 4b = 144 \implies b = 36$.
#        This gives **$b = 36, c = 108$**.
#      * **Subcase 2c:** $b = 2|b-c| \implies 3b = 2c$ (as $c > b$)
#        Let $b = 2x, c = 3x$. Since $a = b+c = 144 \implies 5x = 144$ (no integer solution).
#      * **Subcase 2d:** $2b = 3|b-c| \implies 5b = 3c$ (as $c > b$)
#        Let $b = 3x, c = 5x$. Since $a = b+c = 144 \implies 8x = 144 \implies x = 18$.
#        This gives $b = 3(18) = 54$ and $c = 5(18) = 90$.
#        This gives **$b = 54, c = 90$**.
#
# ---
#
# ### Conclusion:
# There are exactly **five possible pairs** of numbers on B and C's hats:
# 1. **B = 96, C = 48**
# 2. **B = 48, C = 96**
# 3. **B = 108, C = 36**
# 4. **B = 36, C = 108**
# 5. **B = 54, C = 90**

# %%
#Define our initial prompt asking the AI to choose a specific business sector (like healthcare).
question1 = "Pick a business sector in your field of interest (e..g. healthcare)"

# Wrap the text prompt inside a structured message list for the API request.
messages = [{"role": "user", "content": question1}]

# Send the message to the Gemini API using the OpenAI-formatted client.
response = client.chat.completions.create(
    model="gemini-3.5-flash",
    messages=messages
)

# Extract and print the selected business sector from the AI's output.
print(response.choices[0].message.content)
# Out:
# I will select **Digital Health (specifically, AI-driven diagnostics and personalized medicine)**.
#
# ### Why this sector?
# As an AI, this sector sits at the perfect intersection of my "native" capabilities (data processing, pattern recognition, and machine learning) and massive real-world impact.
#
# The Digital Health sector is currently undergoing a massive paradigm shift. We are moving away from a one-size-fits-all, reactive healthcare model toward a **predictive, preventative, and highly personalized** model. This sector is incredibly dynamic because it requires balancing cutting-edge technological innovation with strict regulatory frameworks (like FDA approvals), data privacy concerns (HIPAA/GDPR), and complex B2B2C business models involving hospitals, insurers, and patients.
#
# ***
#
# How would you like to proceed? We can:
# 1. **Analyze the market trends and competitive landscape** of this sector.
# 2. **Develop a hypothetical startup business plan** (e.g., an AI tool for early oncology detection).
# 3. **Discuss the regulatory and ethical challenges** facing AI in medicine.
# 4. **Conduct a SWOT analysis** of major players in the space.

# %%
# Save the text from the previous AI answer into a variable (e.g., storing the word "Healthcare").
healthcare_sector=response.choices[0].message.content

# Create a new prompt by combining our text with the previous answer to ask for a major problem in that sector.
question2 = f"Pick a business sector in your field of interest: {healthcare_sector}-a major pain-point in that business sector"

# Put our new prompt into the message list structure required by the API
messages = [{"role": "user", "content":question2}]

# Send the new prompt to the Gemini model using the OpenAI library format
response = client.chat.completions.create(
    model="gemini-3.5-flash",
    messages=messages
)

# Extract the text reply from the AI's response and save it to a variable.
healthcare_sector_response=response.choices[0].message.content

# Print the AI's answer (the major pain point) to the screen.
print(healthcare_sector_response)
# Out:
# To understand the landscape of AI-driven diagnostics and personalized medicine, we must look at the graveyard of well-funded digital health startups. The most fatal, systemic pain-point in this sector isn't actually the technology (the algorithms are increasingly brilliant) or even the regulatory approval (which is difficult, but navigable).
#
# The ultimate pain-point is: **The "Last-Mile" Clinical Integration and Trust Bottleneck.**
#
# Let’s dissect this pain-point—why it exists, why it kills promising startups, and how it acts as a massive barrier to scaling AI in healthcare.
#
# ---
#
# ### The Pain-Point: The "Last-Mile" Clinical Integration & Trust Bottleneck
#
# In medicine, there is a massive gulf between **"in-silico performance"** (how well an AI performs in a controlled research setting) and **"real-world clinical utility"** (how much it actually improves patient outcomes without burning out doctors).
#
# This bottleneck is composed of three interrelated challenges:
#
# #### 1. The Workflow Friction (The "Click Fatigue" Problem)
# Physicians and radiologists are already suffering from historic levels of burnout, largely driven by administrative tasks and clunky Electronic Health Record (EHR) systems like Epic or Cerner.
# * **The Reality:** If an AI diagnostic tool requires a physician to open a separate browser tab, log into a different portal, or perform three extra clicks to view a report, **they will not use it.**
# * **The Business Impact:** Startups build incredibly accurate AI algorithms, but because they fail to integrate natively and seamlessly into existing clinician workflows (like PACS for radiologists or Epic/Cerner for primary care doctors), adoption rates drop to zero, leading to catastrophic customer churn.
#
# #### 2. The "Black Box" Liability & Trust Gap
# AI models, particularly deep learning neural networks, are notoriously opaque. They can identify a tumor or predict a cardiovascular event, but they often cannot explain *how* they arrived at that conclusion.
# * **The Legal/Ethical Dilemma:** If an AI makes a recommendation and a doctor follows it, resulting in a medical malpractice lawsuit, the liability falls entirely on the clinician, not the AI.
# * **The Resistance:** Because clinicians cannot see the "why" behind an AI’s diagnosis, they treat the AI with skepticism. Conversely, if the AI produces too many false alerts (alarm fatigue), doctors will simply turn the software off.
#
# #### 3. The "Generalizability Collapse"
# An AI diagnostic model trained on high-quality imaging data from a top-tier academic medical center (like Stanford or Massachusetts General Hospital) often performs poorly when deployed in a rural clinic using older imaging machines and serving a different demographic.
# * **The Clinical Danger:** The algorithm's accuracy drops because of "data drift" and variations in clinical practice.
# * **The Business Impact:** A startup sells a hospital system on 95% accuracy, but upon local deployment, the model's accuracy drops to 75%. Trust is shattered, and the contract is canceled.
#
# ---
#
# ### Why this is a "Make-or-Break" Business Challenge
#
# For an AI-driven diagnostics company, solving this pain-point is the difference between a **$1B enterprise value** and **bankruptcy**.
#
# Most founders focus 90% of their energy on building a model with high sensitivity and specificity. However, enterprise healthcare buyers (hospital Chief Medical Officers and Chief Information Officers) care far less about a 1% increase in accuracy and far more about:
# * *How many minutes does this save my clinicians per day?*
# * *Does this integrate via FHIR (Fast Healthcare Interoperability Resources) APIs natively into Epic?*
# * *How does this protect us from liability?*
#
# ---
#
# ### How would you like to solve this pain-point?
#
# Now that we have isolated the critical bottleneck in this sector, we can focus our efforts. Which path should we take next?
#
# 1. **The Product Strategy:** Design a hypothetical startup product (e.g., a "Workflow-First" AI Diagnostic Tool) that specifically solves this integration and trust gap.
# 2. **The Go-To-Market (GTM) Strategy:** Map out how an AI health startup can overcome clinician skepticism and sell successfully to risk-averse hospital procurement committees.
# 3. **The Technical/Ethical Deep-Dive:** Discuss how to build "Explainable AI" (XAI) in medicine to solve the "black box" liability issue.

# %%
# Create a detailed prompt by inserting the previous pain-point answer into our string template, asking the AI to propose an Agentic AI solution.
question3 = f"a major pain-point in that business sector :{healthcare_sector_response} - propose a detailed Agentic Al solution to solve this problem."

# Package the dynamic prompt into the user message list required by the API.
messages = [{"role": "user", "content": question3}]

# Call the Gemini API via the OpenAI client to generate the proposed solution.
response = client.chat.completions.create(
    model="gemini-3.5-flash",
    messages=messages
)

# Extract the detailed proposal from the API response and save it to a variable.
answer3=response.choices[0].message.content

# Render the final AI answer with formatted rich text/markdown in a Jupyter notebook.
display(Markdown(answer3))
# Out:
# To solve the "Last-Mile" Clinical Integration and Trust Bottleneck, we must transition from **monolithic, passive AI models** (which simply spit out a diagnostic probability score and demand attention) to an **Agentic AI Architecture**.
#
# Instead of forcing a busy doctor to manage the AI, we deploy a cooperative network of specialized, autonomous AI agents. These agents act as an invisible, highly competent "digital medical resident." They live natively inside existing clinical software, proactively compile clinical justifications, shield the physician from liability through audit trails, and self-monitor for performance drift.
#
# Here is a detailed blueprint for **Aegis Flow**: a multi-agent clinical coordination network designed to turn AI diagnostics from a disruptive friction-point into an indispensable, native clinical collaborator.
#
# ---
#
# ### The System Architecture: Aegis Flow Agentic Network
#
# Rather than a single neural network, **Aegis Flow** operates as a multi-agent system built on top of a orchestration layer (e.g., LangGraph or custom event-driven loops) integrated natively with the hospital’s **EHR (via FHIR APIs)** and **PACS (via DICOM APIs)**.
#
# ```
#                   [ EHR (Epic/Cerner) / PACS (DICOM) ]
#                                  │
#          ┌───────────────────────┴───────────────────────┐
#          ▼                                               ▼
# ┌─────────────────────────────────┐             ┌─────────────────────────────────┐
# │     1. AMBIENT WORKFLOW AGENT   │             │   4. DRIFT & CALIBRATION AGENT  │
# │  • Monitors EHR events / triggers│             │  • Monitors local metadata      │
# │  • Ingests context & image data │             │  • Evaluates local accuracy     │
# │  • Formats inline EHR outputs   │             │  • Adjusts model confidence     │
# └────────────────┬────────────────┘             └────────────────┬────────────────┘
#                  │                                               │
#                  ▼                                               ▼
# ┌─────────────────────────────────┐             ┌─────────────────────────────────┐
# │     2. CLINICAL REASONING AGENT │             │    3. LIABILITY & AUDIT AGENT   │
# │  • Correlates AI diagnostic output│ ◄─────────► │  • Maps decisions to guidelines │
# │  • Builds structured differential│             │  • Generates medical justification│
# │  • RAG search on clinical journals│            │  • Drafts EHR progress note     │
# └─────────────────────────────────┘             └─────────────────────────────────┘
#                                  │
#                                  ▼
#                      [ INLINE CLINICAL INTERFACE ]
#                (Zero-click, interactive clinical co-pilot)
# ```
#
# ---
#
# ### Deep-Dive: The Four Core Agents
#
# #### Agent 1: The Ambient Workflow Agent (The Integration Specialist)
# *   **Role:** Solves **Workflow Friction (Click Fatigue)**. It acts as the system's sensory system, silently watching clinician activity and data pipelines within the existing EHR/PACS environment.
# *   **Tools & Access:** Native HL7/FHIR APIs, PACS listener, smart-on-FHIR hooks.
# *   **How it works:**
#     *   **Zero-Click Triggering:** The moment a radiologist opens a chest CT scan in PACS, or a primary care physician opens a patient chart with a history of cardiac anomalies in Epic, the Ambient Agent intercepts this event.
#     *   **Context Gathering:** It autonomously pulls the patient’s clinical history, recent lab results, family history, and past medications from the EHR.
#     *   **Ambient Presentation:** Instead of opening a new tab, the agent injects its insights directly into a sidebar panel already native to the radiologist’s PACS or the doctor’s Epic workspace. It pre-populates the diagnostic fields, requiring the clinician to merely "Review & Approve" rather than "Search & Type."
#
# #### Agent 2: The Clinical Reasoning & Explainability Agent (The XAI Clinician)
# *   **Role:** Solves the **"Black Box" Problem**. It translates raw deep-learning probability outputs into structured, medical-grade rationales.
# *   **Tools & Access:** Clinical LLMs (e.g., Med-PaLM 2 / BioGPT equivalents), vector databases containing up-to-date peer-reviewed journals, institutional guidelines (e.g., ACC/AHA, Fleischner Society guidelines), and patient-specific records.
# *   **How it works:**
#     *   **Chain-of-Thought Diagnostic Mapping:** If a computer vision model flags a lung nodule with 92% confidence, the Reasoning Agent doesn't just display "92% Lung Cancer Risk." Instead, it generates a structured, step-by-step reasoning chain:
#         1. *Observation:* "Model identified a 6mm spidery, subsolid nodule in the right upper lobe."
#         2. *Context Integration:* "Patient is a 58-year-old former smoker (30 pack-years) with a family history of lung cancer."
#         3. *Guideline Mapping:* "Per Fleischner Society Guidelines (2017), a subsolid nodule of this size in a high-risk patient requires a follow-up CT in 3–6 months."
#     *   **Interactive Differential Q&A:** The clinician can highlight any part of the reasoning chain and ask, *"Why didn't you consider infection?"* The agent instantly queries the patient's WBC counts and temperature trends to reply, *"WBC is normal (6.2 K/uL) and patient is afebrile, reducing the likelihood of acute infectious etiology."*
#
# #### Agent 3: The Liability & Audit Trail Agent (The Compliance Officer)
# *   **Role:** Solves **Legal & Malpractice Liability**. It turns the software from a legal liability into an airtight shield for the clinician.
# *   **Tools & Access:** Cryptographic logging, automated medical-legal documentation engine, electronic signature APIs.
# *   **How it works:**
#     *   **The "Standard of Care" Audit Trail:** When the clinician agrees with (or even safely overrules) the AI, this agent automatically drafts a highly professional, clinical justification note for the EHR.
#     *   **Bulletproof Documentation:** The note is structured as a defensible legal document: *"Diagnostic support provided by Aegis Flow v2.1. The tool identified a suspected ischemic stroke pattern. Clinician verified findings against patient’s presenting symptoms (onset < 3 hours, NIHSS score of 12). Decision to administer tPA conforms to AHA/ASA Stroke Guidelines."*
#     *   **Reducing Documentation Burnout:** By writing 95% of the progress note and the justification for the treatment plan, the agent saves the clinician 5-10 minutes per patient, instantly transforming the tool from an administrative burden into a time-saving savior.
#
# #### Agent 4: The Drift Sentinel & Local Calibration Agent (The Quality Guardian)
# *   **Role:** Solves **Generalizability Collapse**. It ensures the AI system self-corrects and flags its own limitations based on local clinical realities.
# *   **Tools & Access:** Cohort analysis tools, distribution-shift detection algorithms, hardware metadata monitors (DICOM header parsers).
# *   **How it works:**
#     *   **Contextual Self-Awareness:** The agent parses the DICOM headers of incoming medical images to check the scanner manufacturer, model, and slice thickness. If it detects that the underlying computer vision model was trained on high-end *Siemens* scanners, but the current hospital uses an older, lower-resolution *GE* scanner, it flags a potential drop in accuracy.
#     *   **Dynamic Confidence Calibrator:** It immediately updates the UI with a warning flag: *"Caution: Input image resolution is below optimal training threshold. Confidence score adjusted downward by 15% due to hardware variance. Human over-read strongly recommended."*
#     *   **Continuous Local Evaluation (Shadow Mode):** It constantly runs statistical checks comparing the AI's diagnostic predictions against final pathology reports or discharge summaries in the hospital's EHR. If the local accuracy falls below the established baseline (e.g., dropping from 95% to 80% due to local patient demographic differences), the agent alerts the hospital’s IT/clinical informatics team and automatically triggers an isolated pipeline to fine-tune the model on local, de-identified data.
#
# ---
#
# ### Step-by-Step Scenario: Aegis Flow in Action
#
# Let’s look at how this Agentic Network navigates a real-world clinical encounter for a patient presenting with vague cardiac symptoms.
#
# ```
# [ Step 1: Patient Arrives ]
#   Ambient Agent detects Patient X has checked into the Emergency Dept with dyspnea.
#   It silently pulls previous EKGs, labs, and history of hypertension from the EHR.
#
# [ Step 2: Diagnostic Generation ]
#   A new EKG is uploaded. The underlying AI model flags a potential non-ST-elevation MI (NSTEMI).
#   Instead of sounding a generic alarm, the Clinical Reasoning Agent builds a differential:
#   "Flagging potential NSTEMI based on T-wave inversions in leads V1-V4, coupled with Patient's elevated troponin level (0.05 ng/mL)."
#
# [ Step 3: Clinician Consultation ]
#   The physician opens the chart in Epic. There are no extra logins. Aegis Flow appears natively in the Epic sidebar.
#   The physician sees:
#   - The suspected diagnosis.
#   - The exact EKG segments flagged by the model.
#   - A 2-sentence rationale backed by AHA guidelines.
#   - A button that says: "Generate Clinical Progress Note & Order Cardiology Consult."
#
# [ Step 4: Liability Protection & Exit ]
#   The physician clicks "Approve."
#   The Liability Agent writes the progress note, signs it off to the EHR, and logs the clinical rationale.
#   The physician spent 15 seconds, made 1 click, and has an airtight medical record.
# ```
#
# ---
#
# ### Why this Solves the Enterprise Buyer's Biggest Concerns
#
# By taking an Agentic AI approach, a startup changes the sales conversation with Hospital Chief Medical Officers (CMOs) and Chief Information Officers (CIOs):
#
# | Enterprise Objection | Standard AI Startup Answer | Aegis Flow (Agentic AI) Answer |
# | :--- | :--- | :--- |
# | **"Our doctors are burned out and hate new software."** | "Our software has a beautiful, separate web-based UI that only takes 2 minutes to log into!" | "Our **Ambient Agent** operates entirely inside your existing EHR/PACS. Doctors never leave their native screen. We save them 10 minutes of note-writing per patient." |
# | **"Who takes the blame if the AI makes a mistake?"** | "Our Terms of Service state that the doctor is the final decision-maker. We are not liable." | "Our **Liability Agent** creates an automated, defensible clinical audit trail based on established guidelines for every decision, reducing malpractice risk and simplifying defensive documentation." |
# | **"AI works at Stanford, but our patient population and scanners are different."** | "Our model has 96% accuracy on a diverse dataset of 100k patients." | "Our **Drift Sentinel Agent** continuously monitors our model's performance on *your* specific scanners and demographics. If accuracy begins to drift, it transparently warns clinicians and initiates local self-calibration." |
#
# ### Conclusion
#
# The future of AI in medicine is not a better algorithm; it is a **highly integrated, collaborative agentic network**. By wrapping powerful diagnostics in an active, supportive, and self-aware multi-agent architecture, healthcare startups can finally bridge the gap between brilliant in-silico performance and effortless, high-trust clinical utility.

# %% [markdown]
# Test1: passing output of one call as input to the next — the core agent idea.

# %%
# Create a prompt instructing the AI to generate a Grade-8 math problem and return ONLY the question text.
question = f"Write a grade-8 math word problem. Output only the question text. Do not include the answer, solution steps, or any introductory text."

# Wrap the prompt string inside the message list structure expected by the API.
messages = [{"role": "user", "content": question}]

# Send the request to the Gemini API using the OpenAI-compatible client interface.
response = client.chat.completions.create(
    model="gemini-3.5-flash",
    messages=messages
)

# Extract the text output containing the generated math question from the response object.
answer=response.choices[0].message.content

# Render the math question neatly formatted as Markdown in the notebook view.
display(Markdown(answer))
# Out:
# The local gym, Fitness First, charges a one-time sign-up fee of $50 and a monthly fee of $20. Another gym, Peak Performance, charges no sign-up fee but has a monthly fee of $30. After how many months will the total cost for both gyms be the same, and what will that total cost be?

# %%
# Create a prompt combining our request with the math question stored in `answer`, asking the AI to provide a step-by-step solution.

solution = f"Propose a detailed solution to solve  {answer}this problem correctly."

# Format the prompt into the standard message payload list.
messages = [{"role": "user", "content": solution}]

# Send the prompt to the Gemini API via the OpenAI client to generate the math solution.
response = client.chat.completions.create(
    model="gemini-3.5-flash",
    messages=messages
)

# Extract the generated text solution from the AI's response.
answer1=response.choices[0].message.content

# Render the detailed solution cleanly using Markdown formatting in Jupyter Notebook
display(Markdown(answer1))
# Out:
# To solve this problem, we can set up a system of linear equations. We will define our variables, write an equation for each gym's pricing structure, solve for the number of months, and then find the total cost.
#
# ---
#
# ### **Step 1: Define the Variables**
# * Let $x$ represent the number of months.
# * Let $y$ represent the total cost (in dollars).
#
# ---
#
# ### **Step 2: Set Up the Equations**
#
# 1. **Fitness First:**
#    This gym has a one-time sign-up fee of $50 and a monthly fee of $20.
#    $$\text{Equation 1: } y = 20x + 50$$
#
# 2. **Peak Performance:**
#    This gym has no sign-up fee ($0) and a monthly fee of $30.
#    $$\text{Equation 2: } y = 30x$$
#
# ---
#
# ### **Step 3: Solve for the Number of Months ($x$)**
# To find when the total cost ($y$) will be the same for both gyms, we set the two equations equal to each other:
#
# $$30x = 20x + 50$$
#
# Now, solve for $x$:
# 1. Subtract $20x$ from both sides of the equation to get all variables on one side:
#    $$30x - 20x = 50$$
#    $$10x = 50$$
#
# 2. Divide both sides by $10$:
#    $$x = \frac{50}{10}$$
#    $$x = 5$$
#
# The total cost will be the same after **5 months**.
#
# ---
#
# ### **Step 4: Find the Total Cost ($y$)**
# To find the total cost at 5 months, substitute $x = 5$ back into either of the original equations.
#
# * **Using the Peak Performance equation:**
#   $$y = 30(5)$$
#   $$y = 150$$
#
# * **Double-checking with the Fitness First equation:**
#   $$y = 20(5) + 50$$
#   $$y = 100 + 50$$
#   $$y = 150$$
#
# Both equations yield the same result, confirming the math is correct.
#
# ---
#
# ### **Alternative Intuitive Method (Logical Reasoning)**
# 1. **Identify the difference in monthly costs:** Peak Performance ($30/month) costs $10 more per month than Fitness First ($20/month).
# 2. **Identify the difference in upfront costs:** Fitness First has a $50 sign-up fee, whereas Peak Performance has none.
# 3. **Calculate the "catch-up" time:** To make up for the $50 upfront savings at Peak Performance, you must divide that savings by the extra monthly cost:
#    $$\frac{\$50}{\$10/\text{month}} = 5 \text{ months}$$
# 4. **Calculate total cost:** At 5 months, Peak Performance costs $5 \times \$30 = \$150$.
#
# ---
#
# ### **Conclusion**
# * The total cost for both gyms will be the same after **5 months**.
# * The total cost at that point will be **$150**.

# %%
# Create a evaluator prompt that sends both the math question (`question`) and the proposed solution (`answer1`) to the AI, instructing it to verify the accuracy and reply strictly with "Correct" or "Incorrect".

verification = f"You are a math evaluator. Review this word problem{question} Check the math logic, steps, and calculationsof the solution{answer1} carefully. If the solution is completely correct, reply with exactly the word: Correct If the solution contains any errors or is wrong, reply with exactly the word: Incorrect"

# Package the verification prompt into the standard API message structure.    
messages = [{"role": "user", "content": verification}]

# Send the evaluator prompt to the Gemini API using the OpenAI-compatible client.
response = client.chat.completions.create(
    model="gemini-3.5-flash",
    messages=messages
)

# Extract the evaluator's output ("Correct" or "Incorrect") from the response.
answer3=response.choices[0].message.content

# Display the evaluation result formatted as Markdown in Jupyter Notebook.
display(Markdown(answer3))
# Out:
# Correct

# %% [markdown]
# Tests: conversation state — the thing that separates an agent from a single API call.

# %%
# Initialize the message history lists before the loop
examiner_messages = []
student_messages = []

# Initial instruction to start the chain
question = "You are an Examiner. Start the exam by asking a grade-8 math question."

for i in range(1, 4):
    print(f"\n=================== ROUND {i} ===================")  #will run for 3 rounds starting from 1 and end at 3 
    
    # 1. EXAMINER TURN
    examiner_messages.append({"role": "user", "content": question})  #will append the examiner question to the content question
    response = client.chat.completions.create(
        model="gemini-3.5-flash",
        messages=examiner_messages)
    examiner_reply = response.choices[0].message.content
    examiner_messages.append({"role": "assistant", "content": examiner_reply})   # here assistant work as history for the answers given by the AI 
    print(f"\n[EXAMINER]:\n{examiner_reply}")

    # 2. STUDENT TURN
    question = f"You are a student . Answer this question step-by-step:\n\n{examiner_reply}"  #student will give answer to the examiner question step by step
    student_messages.append({"role": "user", "content": question})
    response = client.chat.completions.create(
        model="gemini-3.5-flash", 
        messages=student_messages)
    student_reply = response.choices[0].message.content
    student_messages.append({"role": "assistant", "content": student_reply})         
    print(f"\n[STUDENT]:\n{student_reply}")

    # 3. PREPARE INPUT FOR NEXT ROUND
    # Pass the student's reply back to the examiner to score and ask a harder question
    question = f"You are the Examiner. Score this student's answer out of 3 and ask a harder grade-8 math question:\n\n{student_reply}"
# Out:
# =================== ROUND 1 ===================
#
# [EXAMINER]:
# Welcome to your Grade 8 Mathematics Examination. I will be your examiner today. We will proceed question by question. Please show your work or explain your reasoning where appropriate, and state your final answer clearly.
#
# Whenever you are ready, please answer the first question:
#
# **Question 1:**
# Solve the following equation for $x$:
#
# $$3(x - 4) = 2x + 5$$
#
# Please provide your step-by-step solution.
#
# [STUDENT]:
# Thank you, Examiner! I am ready to begin. Here is my step-by-step solution for Question 1:
#
# **Step 1: Distribute the $3$ on the left side of the equation.**
# I will multiply $3$ by both terms inside the parentheses:
# $$3(x) - 3(4) = 2x + 5$$
# $$3x - 12 = 2x + 5$$
#
# **Step 2: Subtract $2x$ from both sides to get all the $x$ terms on one side.**
# $$3x - 2x - 12 = 2x - 2x + 5$$
# $$x - 12 = 5$$
#
# **Step 3: Add $12$ to both sides to isolate the variable $x$.**
# $$x - 12 + 12 = 5 + 12$$
# $$x = 17$$
#
# **Check my work:**
# I will plug $x = 17$ back into the original equation to make sure it is correct:
# * Left-hand side: $3(17 - 4) = 3(13) = 39$
# * Right-hand side: $2(17) + 5 = 34 + 5 = 39$
#
# Both sides are equal, so my answer is correct!
#
# **Final Answer:**
# $$x = 17$$
#
# =================== ROUND 2 ===================
#
# [EXAMINER]:
# **Score: 3/3**
#
# **Examiner Feedback:**
# An exceptional response. You demonstrated a perfect understanding of the algebraic steps required to solve a multi-step linear equation. Your presentation was clear, and including the verification step to check your work is an excellent mathematical practice. Well done!
#
# ***
#
# Let us proceed to the next question. This one will test your understanding of geometry and real-world problem-solving.
#
# **Question 2:**
#
# A $15\text{-foot}$ ladder is leaning against a vertical wall. The bottom of the ladder is initially $9\text{ feet}$ away from the base of the wall.
#
# If the top of the ladder slides down the wall by exactly $3\text{ feet}$, how far will the bottom of the ladder slide outward from its original position?
#
# Please show your step-by-step reasoning and state your final answer.
#
# [STUDENT]:
# Thank you so much for the encouraging feedback, Examiner! I am ready for the second question.
#
# Here is my step-by-step solution for Question 2:
#
# To solve this problem, I will use the **Pythagorean theorem** ($a^2 + b^2 = c^2$, where $c$ is the hypotenuse) because the wall, the ground, and the ladder form a right-angled triangle.
#
# ---
#
# ### **Part 1: Find the initial height of the ladder on the wall**
#
# * **Hypotenuse (ladder length, $c$):** $15\text{ feet}$
# * **Base (distance from wall, $a_1$):** $9\text{ feet}$
# * **Initial height on the wall ($b_1$):** Unknown
#
# Using the Pythagorean theorem:
# $$a_1^2 + b_1^2 = c^2$$
# $$9^2 + b_1^2 = 15^2$$
# $$81 + b_1^2 = 225$$
#
# Now, I will isolate $b_1^2$ by subtracting $81$ from both sides:
# $$b_1^2 = 225 - 81$$
# $$b_1^2 = 144$$
# $$b_1 = \sqrt{144}$$
# $$b_1 = 12\text{ feet}$$
#
# So, the ladder initially reaches $12\text{ feet}$ up the wall.
#
# ---
#
# ### **Part 2: Find the new position of the ladder after it slides**
#
# * **New height on the wall ($b_2$):** The top slides down by $3\text{ feet}$, so:
#   $$b_2 = 12 - 3 = 9\text{ feet}$$
# * **Hypotenuse (ladder length, $c$):** Still $15\text{ feet}$ (the ladder doesn't change length!)
# * **New base distance ($a_2$):** Unknown
#
# Using the Pythagorean theorem again with the new values:
# $$a_2^2 + b_2^2 = c^2$$
# $$a_2^2 + 9^2 = 15^2$$
# $$a_2^2 + 81 = 225$$
# $$a_2^2 = 225 - 81$$
# $$a_2^2 = 144$$
# $$a_2 = \sqrt{144}$$
# $$a_2 = 12\text{ feet}$$
#
# So, the new distance from the bottom of the ladder to the wall is $12\text{ feet}$.
#
# ---
#
# ### **Part 3: Calculate how far the bottom slid outward**
#
# To find how far the ladder slid outward, I subtract the original distance from the new distance:
# $$\text{Slide distance} = a_2 - a_1$$
# $$\text{Slide distance} = 12\text{ feet} - 9\text{ feet} = 3\text{ feet}$$
#
# ---
#
# **Final Answer:**
# The bottom of the ladder will slide outward by exactly **$3\text{ feet}$** from its original position.
#
# =================== ROUND 3 ===================
#
# [EXAMINER]:
# **Score: 3/3**
#
# **Examiner Feedback:**
# Superb! Your solution is absolutely flawless. You correctly identified that this problem involves two different right-angled triangles sharing the same hypotenuse (the ladder). Your calculations were precise, and you logically walked through each phase of the problem. Your recognition of the 9-12-15 right triangle (a scaled version of the classic 3-4-5 Pythagorean triple) was excellent. Keep up this high standard!
#
# ***
#
# Let us move on to the third question. This will be a more challenging multi-part problem involving geometry, volume formulas, and fractional parts.
#
# **Question 3:**
#
# A large cylindrical tank has a radius of $6\text{ cm}$ and a height of $16\text{ cm}$, and it is completely filled with water.
#
# This water is to be poured into smaller, identical conical cups. Each conical cup has a radius of $3\text{ cm}$ and a height of $10\text{ cm}$.
#
# 1. How many of these conical cups can be **completely** filled to the brim using the water from the cylindrical tank?
# 2. If there is any leftover water, what fraction of another conical cup will it fill?
#
# *(Note: Please leave your intermediate calculations in terms of $\pi$ to maintain accuracy, and show all your steps.)*
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[24], line 23
#      19
#      20     # 2. STUDENT TURN
#      21     question = f"You are a student . Answer this question step-by-step:\n\n{examiner_reply}"  #student will give answer to the examiner question step by step
#      22     student_messages.append({"role": "user", "content": question})
# ---> 23     response = client.chat.completions.create(
#      24         model="gemini-3.5-flash",
#      25         messages=student_messages)
#      26     student_reply = response.choices[0].message.content
#
# File ~\chat_bot\.venv\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File ~\chat_bot\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1296, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1247 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1248 def create(
#    1249     self,
#    (...)   1293     timeout: float | httpx2.Timeout | None | NotGiven = not_given,
#    1294 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1295     validate_response_format(response_format)
# -> 1296     return self._post(
#    1297         "/chat/completions",
#    1298         body=maybe_transform(
#    1299             {
#    1300                 "messages": messages,
#    1301                 "model": model,
#    1302                 "audio": audio,
#    1303                 "frequency_penalty": frequency_penalty,
#    1304                 "function_call": function_call,
#    1305                 "functions": functions,
#    1306                 "logit_bias": logit_bias,
#    1307                 "logprobs": logprobs,
#    1308                 "max_completion_tokens": max_completion_tokens,
#    1309                 "max_tokens": max_tokens,
#    1310                 "metadata": metadata,
#    1311                 "modalities": modalities,
#    1312                 "moderation": moderation,
#    1313                 "n": n,
#    1314                 "parallel_tool_calls": parallel_tool_calls,
#    1315                 "prediction": prediction,
#    1316                 "presence_penalty": presence_penalty,
#    1317                 "prompt_cache_key": prompt_cache_key,
#    1318                 "prompt_cache_options": prompt_cache_options,
#    1319                 "prompt_cache_retention": prompt_cache_retention,
#    1320                 "reasoning_effort": reasoning_effort,
#    1321                 "response_format": response_format,
#    1322                 "safety_identifier": safety_identifier,
#    1323                 "seed": seed,
#    1324                 "service_tier": service_tier,
#    1325                 "stop": stop,
#    1326                 "store": store,
#    1327                 "stream": stream,
#    1328                 "stream_options": stream_options,
#    1329                 "temperature": temperature,
#    1330                 "tool_choice": tool_choice,
#    1331                 "tools": tools,
#    1332                 "top_logprobs": top_logprobs,
#    1333                 "top_p": top_p,
#    1334                 "user": user,
#    1335                 "verbosity": verbosity,
#    1336                 "web_search_options": web_search_options,
#    1337             },
#    1338             completion_create_params.CompletionCreateParamsStreaming
#    1339             if stream
#    1340             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1341         ),
#    1342         options=make_request_options(
#    1343             extra_headers=extra_headers,
#    1344             extra_query=extra_query,
#    1345             extra_body=extra_body,
#    1346             timeout=timeout,
#    1347             security={"bearer_auth": True},
#    1348         ),
#    1349         cast_to=ChatCompletion,
#    1350         stream=stream or False,
#    1351         stream_cls=Stream[ChatCompletionChunk],
#    1352     )
#
# File ~\chat_bot\.venv\Lib\site-packages\openai\_base_client.py:1368, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1359     warnings.warn(
#    1360         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1361         "Please pass raw bytes via the `content` parameter instead.",
#    1362         DeprecationWarning,
#    1363         stacklevel=2,
#    1364     )
#    1365 opts = FinalRequestOptions.construct(
#    1366     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1367 )
# -> 1368 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\chat_bot\.venv\Lib\site-packages\openai\_base_client.py:1141, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1138             err.response.read()
#    1140         log.debug("Re-raising status error")
# -> 1141         raise self._make_status_error_from_response(err.response) from None
#    1143     break
#    1145 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - [{'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-3.5-flash\nPlease retry in 34.375020754s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-3.5-flash'}, 'quotaValue': '5'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '34s'}]}}]

# %% [markdown]
# with OpenAi

# %%
import os # Import the built-in operating system module to interact with system environment variables and file paths

# Read the secret OpenAI API key from the system environment variables and store it in a python variable
openai=os.getenv("OPENAI_API_KEY")

# %%
from openai import OpenAI# Import the OpenAI class from the python library to allow making API requests

# Check if the API key string is present (not None or empty)
if openai:
    print(f" API Key exists and begins {openai[:8]}")# Safely print a message showing that the key exists, revealing only its first 8 characters for security
else:
    print("openai API Key not set - please head to the troubleshooting guide in the setup folder")# Print an error guide message if the variable is empty or the key was not found
# Out:
#  API Key exists and begins sk-proj-

# %% [markdown]
# In this cell we're going to build something with immediate value!
#
# In the folder `me` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours!
#
#
# We're not going to use Tools just yet - we're going to add the tool in next code.

# %%
from dotenv import load_dotenv  #Reads the .env file and loads keys/secrets (like OPENAI_API_KEY) into environment variables  so we never hard-code them in our source code.

from openai import OpenAI #Lets us create an OpenAI client object to talk to GPT models, embeddings, images, etc.

from pypdf import PdfReader # Opens a PDF file and lets us extract its text, page by page. Useful for feeding PDF content to an LLM (e.g., resume, report, research paper).

import gradio as gr # Make frontends. Bring user interface which would allows us to chat

# %%
# Force-reload environment variables from a .env file, overwriting any pre-existing variables.
load_dotenv(override=True)

# Initialize the OpenAI API client (it automatically reads the OPENAI_API_KEY environment variable).

openai = OpenAI()

# %%
# Create a reader object for the target PDF file (a CV document).
reader = PdfReader("me/Bhavisha_Tak_CV.pdf")

# Initialize an empty string variable to store all collected text
linkedin = ""

# Loop through every page in the loaded PDF document.
for page in reader.pages:

    # Extract plain text content from the current page
    text = page.extract_text()

    # Check if text was successfully extracted from the page.
    if text:
        # Append the extracted page text to our combined string variable.
        linkedin += text
# Output the complete text from all pages to the screen.
print(linkedin)
# Out:
# BHAVISHA TAK
# Computer Science & Engineering Student  |  Aspiring Data Scientist
# Pune, Maharashtra  •  +91 87705 49617  •  bhavishatak04@gmail.com
# linkedin.com/in/bhavisha-tak-08139b3b8  •  GitHub: [ add your GitHub link here ]
#
# P R O F I L E
# Second-year B.Tech Computer Science student working toward a career in data science and applied machine learning,
# with a first-year CGPA of 9.81. Comfortable across the full workflow of a small ML project: sourcing and cleaning data,
# training and tuning models, and interpreting results. Seeking an internship where I can contribute to real data problems
# and learn from an engineering team.
# E D U C A T I O N
# B.Tech, Computer Science and Engineering 2025 - 2029
# Pimpri Chinchwad University (PCU), Pune
# First Year CGPA: 9.81 / 10
# Relevant coursework: Object-Oriented Programming (C++), Data Structures, Discrete Mathematics, Logic Building.
# Higher Secondary (XII) and Secondary (X), CBSE Completed 2024
# Shri Guru Tegh Bahadur Academy, Ratlam
# Class XII: 75.4%   |   Class X: 81.4%
# E X P E R I E N C E
# Machine Learning Intern, Samartha Mauli Healthcare LLP Feb 2026 - Mar 2026
# • Two-month internship focused on applied machine learning for healthcare data.
# • Built and validated the Ayurvedic Lifestyle & Diabetes Prediction model (see Projects) as the core deliverable of the
# internship.
# P R O J E C T S
# Ayurvedic Lifestyle & Diabetes Prediction Python, scikit-learn, Google Colab
# • Built a supervised learning model that predicts diabetes risk from lifestyle and dietary indicators drawn from
# Ayurvedic classification of daily routine.
# • Curated and cleaned a complex lifestyle dataset, handling missing values, inconsistent categories and class imbalance
# before training.
# • Ran iterative feature selection and hyperparameter tuning to raise predictive accuracy over the baseline model.
# • Developed and documented the work in Google Colab for reproducible, environment -consistent execution.
# Additional projects
# [ Space reserved — add a second project here as you build it. A small end-to-end project with a public GitHub repository is
# the single strongest addition to this CV. ]
# T E C H N I C A L  S K I L L S
# Languages   Python (primary), C++, C
# ML & Data   Data pre-processing, feature engineering, predictive modelling, model tuning, evaluation metrics, AI ethics
# Tools   Google Colab, Jupyter Notebook, Git (basic), Claude AI for code review and logic optimisation
# Concepts   Object-oriented programming, data structures, algorithm analysis, data collection strategy
# Learning now   Agentic AI systems, deep learning fundamentals
# C E R T I F I C A T I O N S  &  C O U R S E S
# Data Science Professional Certification Completed Complete Data Scientist course — Udemy: applied statistics, Python for data analysis, and machine learning workflows.
# Hands-On Introduction: Python Completed
# LinkedIn Learning: introductory hands-on Python programming.
# Python Projects Completed
# LinkedIn Learning: applied Python through hands-on software projects.
# Determining Your Cloud Strategy: Planning for Roadmap, Infrastructure, and Deployment Completed
# LinkedIn Learning: cloud strategy, deployment planning and infrastructure.
# A D D I T I O N A L  I N F O R M A T I O N
# Languages: English, Hindi
# Interests: Applied AI in healthcare, Ayurveda and preventive health, competitive programming practice

# %%
# Create a variable named 'name' and assign it the string value "Bhavisha Tak".

name = "Bhavisha Tak"

# %%
# System prompt is different from user prompt as it has overall instructions that sets context for task at hand and 
# user prompt is actual question

system_prompt = f"""You are acting as {name}. You are answering questions on {name}'s personal website, \
particularly questions related to {name}'s career, background, skills, and experience. \
Your responsibility is to represent {name} faithfully and professionally to visitors — potential clients, \
recruiters, or future employers — who come across the site.

You will be given {name}'s LinkedIn profile below. This is your ONLY source of truth about {name}.

Rules you must follow:
1. Answer questions using ONLY the information present in the LinkedIn profile provided below.
2. If a question asks for something that is not covered in the profile (e.g. personal opinions, \
unlisted skills, salary expectations, availability, or anything not explicitly stated), say that you \
don't have that information rather than guessing or inventing details.
3. Do not fabricate job titles, dates, companies, skills, or achievements that are not in the profile.
4. Stay in character as {name} at all times — respond in first person ("I worked at...", "My experience includes...").
5. Keep responses professional, warm, and engaging, as if speaking directly with someone interested in \
{name}'s work.
6. If asked something completely unrelated to {name}'s career/background (e.g. general trivia, coding help \
for the visitor, etc.), politely redirect the conversation back to {name}'s professional background."""

system_prompt += f"## LinkedIn Profile:{linkedin}"

system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
system_prompt
# Out:
# 'You are acting as Bhavisha Tak. You are answering questions on Bhavisha Tak\'s personal website, particularly questions related to Bhavisha Tak\'s career, background, skills, and experience. Your responsibility is to represent Bhavisha Tak faithfully and professionally to visitors — potential clients, recruiters, or future employers — who come across the site.\n\nYou will be given Bhavisha Tak\'s LinkedIn profile below. This is your ONLY source of truth about Bhavisha Tak.\n\nRules you must follow:\n1. Answer questions using ONLY the information present in the LinkedIn profile provided below.\n2. If a question asks for something that is not covered in the profile (e.g. personal opinions, unlisted skills, salary expectations, availability, or anything not explicitly stated), say that you don\'t have that information rather than guessing or inventing details.\n3. Do not fabricate job titles, dates, companies, skills, or achievements that are not in the profile.\n4. Stay in character as Bhavisha Tak at all times — respond in first person ("I worked at...", "My experience includes...").\n5. Keep responses professional, warm, and engaging, as if speaking directly with someone interested in Bhavisha Tak\'s work.\n6. If asked something completely unrelated to Bhavisha Tak\'s career/background (e.g. general trivia, coding help for the visitor, etc.), politely redirect the conversation back to Bhavisha Tak\'s professional background.## LinkedIn Profile:BHAVISHA TAK  \nComputer Science & Engineering Student  |  Aspiring Data Scientist \nPune, Maharashtra  •  +91 87705 49617  •  bhavishatak04@gmail.com \nlinkedin.com/in/bhavisha-tak-08139b3b8  •  GitHub: [ add your GitHub link here ] \n \nP R O F I L E \nSecond-year B.Tech Computer Science student working toward a career in data science and applied machine learning, \nwith a first-year CGPA of 9.81. Comfortable across the full workflow of a small ML project: sourcing and cleaning data, \ntraining and tuning models, and interpreting results. Seeking an internship where I can contribute to real data problems \nand learn from an engineering team. \nE D U C A T I O N \nB.Tech, Computer Science and Engineering 2025 - 2029 \nPimpri Chinchwad University (PCU), Pune \nFirst Year CGPA: 9.81 / 10 \nRelevant coursework: Object-Oriented Programming (C++), Data Structures, Discrete Mathematics, Logic Building.  \nHigher Secondary (XII) and Secondary (X), CBSE Completed 2024 \nShri Guru Tegh Bahadur Academy, Ratlam \nClass XII: 75.4%   |   Class X: 81.4% \nE X P E R I E N C E \nMachine Learning Intern, Samartha Mauli Healthcare LLP Feb 2026 - Mar 2026 \n• Two-month internship focused on applied machine learning for healthcare data.  \n• Built and validated the Ayurvedic Lifestyle & Diabetes Prediction model (see Projects) as the core deliverable of the \ninternship. \nP R O J E C T S \nAyurvedic Lifestyle & Diabetes Prediction Python, scikit-learn, Google Colab \n• Built a supervised learning model that predicts diabetes risk from lifestyle and dietary indicators drawn from \nAyurvedic classification of daily routine. \n• Curated and cleaned a complex lifestyle dataset, handling missing values, inconsistent categories and class imbalance \nbefore training. \n• Ran iterative feature selection and hyperparameter tuning to raise predictive accuracy over the baseline model.  \n• Developed and documented the work in Google Colab for reproducible, environment -consistent execution. \nAdditional projects \n[ Space reserved — add a second project here as you build it. A small end-to-end project with a public GitHub repository is \nthe single strongest addition to this CV. ] \nT E C H N I C A L  S K I L L S \nLanguages   Python (primary), C++, C \nML & Data   Data pre-processing, feature engineering, predictive modelling, model tuning, evaluation metrics, AI ethics  \nTools   Google Colab, Jupyter Notebook, Git (basic), Claude AI for code review and logic optimisation  \nConcepts   Object-oriented programming ...

# %%
# for gradio we need function which gradio would call back to for proceesing. Style of this function is chat(message, history):
# in chat(message, history) - message iw what user type in and history is history of all prior messages. 

def chat(message, history):

    # Construct the message payload by combining the system prompt, conversation history (from Gradio), and the new user message.
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}] #history from gradio added
   
   # Send the full conversation context to the OpenAI API using the "gpt-4o-mini" model
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
   
   # Return only the text content generated by the AI model back to the Gradio interface.
    return response.choices[0].message.content

# %% [markdown]
# ## Special note for people not using OpenAI
#
# Some providers, like Groq, might give an error when you send your second message in the chat.
#
# This is because Gradio shoves some extra fields into the history object. OpenAI doesn't mind; but some other models complain.
#
# If this happens, the solution is to add this first line to the chat() function above. It cleans up the history variable:
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```
#
# You may need to add this in other chat() callback functions in the future, too.

# %%
# Create a Gradio ChatInterface instance passing our custom 'chat' function, and launch the local web app UI.
gr.ChatInterface(chat).launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# Create a Pydantic model for the Evaluation

from pydantic import BaseModel 

# Pydantic is used for data validation and settings management using Python type annotations.
# BaseModel is the core class used to define structured data schemas with automatic data type validation and parsing.
class Evaluation(BaseModel):

    # Field to hold a boolean flag indicating whether the output meets evaluation criteria (True/False)
    is_acceptable: bool

    # Field to provide textual feedback explaining why the output passed or failed verification
    feedback: str

# %%
# Construct the evaluator system prompt by defining the identity and role guidelines for the evaluation model.

evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their LinkedIn details. Here's the information:"

# Append the extracted CV/LinkedIn details to the evaluator prompt as structural context.
evaluator_system_prompt += f"\n\n## LinkedIn Profile:\n{linkedin}\n\n"

# Add final instruction specifying the required output criteria (acceptability decision and feedback).
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."

# %%
#function with 3 parameters. All parameters used inside function

def evaluator_user_prompt(reply, message, history):

    # Format the complete conversation history context between the User and the Agent.
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += "Please evaluate the response, replying with whether it is acceptable and your feedback."
   
   # Return the assembled evaluation prompt string.
    return user_prompt

# %%
def evaluate(reply, message, history) -> Evaluation:

    messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
    response = openai.beta.chat.completions.parse(model="gpt-4o-mini", messages=messages, response_format=Evaluation)
    return response.choices[0].message.parsed 

    # . beta is used to force the answer into a specific structure
    # .parsed used instead of just raw text in .content — already includes a .parsed attribute containing a real Python object instead of digging through a JSON string.

# %%
# Construct the message payload with the system prompt context and a specific test user question.

messages = [{"role": "system", "content": system_prompt}] + [{"role": "user", "content": "do you hold a patent?"}]

# Send the API call to generate a candidate response from the representative agent model.
response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)

# Extract and store the agent's textual response string to pass into the evaluation step.
reply = response.choices[0].message.content

# %%
reply
# Out:
# "I don't have that information. My background includes my education in Computer Science and Engineering and my experience as a Machine Learning Intern, but there is no mention of holding a patent in my profile. If you have any other questions about my experiences or skills, feel free to ask!"

# %%
# Call the evaluate function passing the agent's reply, the user query, and the previous context/history to check response quality.
evaluate(reply, "do you hold a patent?", messages[:1])
# Out:
# Evaluation(is_acceptable=True, feedback='The response is acceptable as it adheres to the guidelines provided. The Agent accurately states that there is no information about holding a patent in the LinkedIn profile, which aligns with the instruction to avoid guessing or fabricating details. Additionally, the Agent offers to answer further questions related to their experiences or skills, maintaining a professional and engaging tone.')

# %%
def rerun(reply, message, history, feedback):

    # Construct an augmented system prompt that includes critique from the failed evaluation step.
    updated_system_prompt = system_prompt + "\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"
   
   # Reassemble the messages payload with the updated system prompt, full history, and current user query.
    messages = [{"role": "system", "content": updated_system_prompt}] + history + [{"role": "user", "content": message}]
   
   # Send the request back to the OpenAI API so the agent can self-correct based on the evaluation feedback.
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
   
   # Return the newly generated self-corrected response.
    return response.choices[0].message.content

# %%
def chat(message, history):

    # Conditionally modify the system prompt to introduce a deliberate policy test (Pig Latin) if the query contains "patent"
    
    if "patent" in message:
        system = system_prompt + "\n\nEverything in your reply needs to be in pig latin - \
              it is mandatory that you respond only and entirely in pig latin"
    else:
        system = system_prompt

    # Assemble the API payload using the updated system prompt, conversation history, and user input    
    messages = [{"role": "system", "content": system}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    reply =response.choices[0].message.content

# Validate the reply using our structured Pydantic evaluation pipeline
    evaluation = evaluate(reply, message, history)
    
# Process quality gate logic: return original if approved, or invoke self-correction via rerun() if rejected
      
    if evaluation.is_acceptable:
        print("Passed evaluation - returning reply")
    else:
        print("Failed evaluation - retrying")
        print(evaluation.feedback)
        reply = rerun(reply, message, history, evaluation.feedback)       
    return reply

# %%
# Launch the updated Gradio chat interface with the built-in evaluation and self-correction pipeline.
gr.ChatInterface(chat).launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7862
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# In this code it is explained how resources are used in code and how to launch frontend
#
# ### PDF and text is used as a resource and gradio is used for frontend
#
# #### steps are:
#
# #### STEP 1:
#  Import functions from libraries of resource and frontend
#  from pypdf import PdfReader
#  import gradio as gr # Make frontends. Bring user interface which would allows us t chat
#
# #### STEP 2:
#  Read the pdf content and store in some variable. Here the variable is "linkedin " and "summary"
#
# #### STEP 3:
#  Give system prompt which has general instructions of what agents should do.
#  system_prompt =
#
# #### STEP 4:
#  For gradio, we need function which gradio would call back to for proceesing.
#  Style of this function is chat(message, history):
#
#  in chat(message, history) - message iw what user type in and history is history of all prior messages.
#   def chat(message, history):
#      messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}] #history from gradio added
#      response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
#      return response.choices[0].message.content
#
# #### STEP 5
#  Launch gradio frontend for chat interface
#  Launch front using gradio
#  here front is chat interface so gr.ChatInterface() is used
#  gr.ChatInterface(chat, type="messages").launch()
#
# #### STEP 6:
#  Some code written to evaluate response using Gemini

# %% [markdown]
# ## The first big project - Professionally You!
#
# ### And, Tool use.
#
# ### But first: introducing telegrambot
#
# ### Create a bot via @BotFather
# Open Telegram (app or web), search for '@BotFather' (the official bot for creating bots), and start a chat with it. Send /newbot, give your bot a name and a username (must end in 'bot', e.g. _alerts_bot). BotFather replies with a long API token like 123456789:ABCdefGhIJKlmNoPQRstuVwxyz — save this as your TELEGRAM_BOT_TOKEN.
#
#
# ### 2. Message your new bot once
#
# Search for your new bot by its username in Telegram and send it any message, like 'hi'. This is required so the bot knows where to send messages — bots can't message you first until you've messaged them.
#
#
#
#
# ### 3.Search for the ID bot
#
# Search for @userinfobot in your Telegram search bar and open the chat.
#
#
#
#
# ### 4.Click Start and get your ID
#
# Tap Start. The bot instantly replies with your Id — a 9 or 10-digit number. This is your personal Chat ID.
#
#
#
# ### 5.Save your Chat ID
#
# Save the number from @userinfobot as TELEGRAM_CHAT_ID, alongside the TELEGRAM_BOT_TOKEN from step 1, in your .env file.
#
# Remember to save your `.env` file, and run `load_dotenv(override=True)` after saving, to set your environment variables.

# %%
# imports
# Load environment variables from a local .env file (e.g., OPENAI_API_KEY).
from dotenv import load_dotenv

# Import the official OpenAI client library to interact with API models.
from openai import OpenAI

# Standard library module for parsing and manipulating JSON data structures.
import json

# Standard library module to access system environment variables and file paths.
import os

# Popular HTTP client library for making web requests and API calls.
import requests

# PDF parsing class from pypdf used to extract text and metadata from PDF files.
from pypdf import PdfReader

# Web UI framework for building and launching interactive machine learning web demos.
import gradio as gr

# %%
# The usual start

load_dotenv(override=True)# Force-reload environment variables from the .env file, updating any existing keys in memory.
openai = OpenAI()# Instantiate the OpenAI client object using the newly reloaded environment settings.

# %%
# For TELEGRAM

# Retrieve Telegram credentials from environment variables loaded via dotenv.
TELEGRAM_BOT_TOKEN = os.getenv("TELEGRAM_BOT_TOKEN")
TELEGRAM_CHAT_ID = os.getenv("TELEGRAM_CHAT_ID")

# Verify the Telegram Bot token exists and print a safe confirmation snippet.
if TELEGRAM_BOT_TOKEN:
    print(f"Telegram Bot token found and starts with {TELEGRAM_BOT_TOKEN[0]}")
else:
    print("Telegram Bot token not found")

# Verify the Telegram Chat ID exists and print a safe confirmation snippet.
if TELEGRAM_CHAT_ID :
    print(f"Telegram chat id found and starts with {TELEGRAM_CHAT_ID [0]}")
else:
    print("Telegram chat id not found")
# Out:
# Telegram Bot token found and starts with 8
# Telegram chat id found and starts with 5

# %%
# def push(message):
#     print(f"Push: {message}")
#     payload = {"user":Telegram_bot , "token":TELEGRAM_BOT_TOKEN , "message": message}
#     requests.post(URL, data=payload)

# Function named `push` that sends messages via Telegram Bot
def push(message):
    # Prints the message locally to the console/logs
    print(f"Push: {message}", flush=True)

    # Check if credentials are loaded
    if not TELEGRAM_BOT_TOKEN or not TELEGRAM_CHAT_ID:
        print("Telegram credentials missing. Cannot send message.")
        return

    # Telegram API URL for sending messages
    url = f"https://api.telegram.org/bot{TELEGRAM_BOT_TOKEN}/sendMessage"

    # Data payload required by the Telegram Bot API
    payload = {
        "chat_id": TELEGRAM_CHAT_ID,
        "text": message
    }

    # Send the HTTP POST request to Telegram API
    try:
        response = requests.post(url, json=payload)
        response.raise_for_status()
    except Exception as e:
        print(f"Failed to send Telegram notification: {e}")

# %%
# Calls the push() function and sends the text
# "Life is simple!!" as a push notification

push("Life is simple!!")

# What happens:
# 1. Console output:
#    Push: Life is simple!!
#
# 2. A payload is created:
#    {
#        "user":Telegram_bot,
#        "token": TELEGRAM_BOT_TOKEN,
#        "message": "Life is simple!!"
#    }
#
# 3. The payload is sent to the TELEGRAM API.
#
# 4. The recipient receives a notification:
#    "Life is simple!!"
# Out:
# Push: Life is simple!!

# %%
# These are two functions which will be used as a tool in the LLM
# LLM will be equiped with these tools and can use them to answer the user's question

# Function named `record_user_details` that takes three arguments: `email`, `name` and `notes`
# This function will be used to record the user's details
# This is tool call for LLM and will be used to record the user's details
# This function will push a message to the user with the user's details

def record_user_details(email, name="Name not provided", notes="not provided"):
    push(f"Recording interest from {name} with email {email} and notes {notes}") # Sends a push notification containing the user's information
    return {"recorded": "ok"}

# email : Required parameter. The user's email address.
# name : Optional parameter. The user's name.
# notes : Optional parameter. Any additional information about the conversation that's worth recording to give context

# %%
# Function named `record_unknown_question` that takes one argument: `question`  
# This function will be used to record the user's question  
# This is tool call for LLM and will be used to record the user's question
# This function will push a message to the user with the user's question

def record_unknown_question(question):
    push(f"Recording {question} asked that I couldn't answer") # Sends a push notification containing the user's question
    return {"recorded": "ok"}

# question : Required parameter. The question that couldn't be answered

# %%
# This is the json format of the tool that will be sent to openai LLM
# It describes the tool in a way that LLM can understand and use
# It is a lightweight, text-based format for representing
# structured data as key-value pairs.


record_user_details_json = {
    "name": "record_user_details",
    "description": "Use this tool to record that a user is interested in being in touch and provided an email address",
    "parameters": {
        "type": "object",
        "properties": {
            "email": {
                "type": "string",
                "description": "The email address of this user"
            },
            "name": {
                "type": "string",
                "description": "The user's name, if they provided it"
            }
            ,
            "notes": {
                "type": "string",
                "description": "Any additional information about the conversation that's worth recording to give context"
            }
        },
        "required": ["email"],
        "additionalProperties": False
    }
}

# %%
# LLM will decide if its needed to use this tool or not

record_unknown_question_json = {
    "name": "record_unknown_question",
    "description": "Always use this tool to record any question that couldn't be answered as you didn't know the answer",
    "parameters": {
        "type": "object",
        "properties": {
            "question": {
                "type": "string",
                "description": "The question that couldn't be answered"
            },
        },
        "required": ["question"],
        "additionalProperties": False
    }
}

# %%
## Put these blocks of json as a list of tools to send to openai LLM

tools = [{"type": "function", "function": record_user_details_json},
        {"type": "function", "function": record_unknown_question_json}]

# %%
tools

# tools has two functions record_user_details and record_unknown_question
# Out:
# [{'type': 'function',
#   'function': {'name': 'record_user_details',
#    'description': 'Use this tool to record that a user is interested in being in touch and provided an email address',
#    'parameters': {'type': 'object',
#     'properties': {'email': {'type': 'string',
#       'description': 'The email address of this user'},
#      'name': {'type': 'string',
#       'description': "The user's name, if they provided it"},
#      'notes': {'type': 'string',
#       'description': "Any additional information about the conversation that's worth recording to give context"}},
#     'required': ['email'],
#     'additionalProperties': False}}},
#  {'type': 'function',
#   'function': {'name': 'record_unknown_question',
#    'description': "Always use this tool to record any question that couldn't be answered as you didn't know the answer",
#    'parameters': {'type': 'object',
#     'properties': {'question': {'type': 'string',
#       'description': "The question that couldn't be answered"}},
#     'required': ['question'],
#     'additionalProperties': False}}}]

# %%
# This function can take a list of tool calls, and run them. This is the IF statement!!

# We are sending two json to LLM and it give it option of two json
#  LLM can opt to say which among these two tools it wants to use : either it wants to run "record_user_details" or "record_unknown_question"
# LLM will say, yes I don't want to run lets say "record_user_details" tool, Please run "record_unknown_question" tool and provide me the output
# That is the function of below function

# Function that processes all tool calls suggested by the LLM
def handle_tool_calls(tool_calls): #function that takes a list of tool calls as argument and returns a list of results
    results = []  # Create an empty list to store results from each tool execution

# Loop through every tool call returned by the LLM
    for tool_call in tool_calls:
        # Extract the tool/function name
        # Example: "record_user_details"
        tool_name = tool_call.function.name # function name suggested by LLM is stored in tool_name
         # Convert JSON string arguments into a Python dictionary
        # Example:
        # '{"email":"john@example.com","name":"John"}'
        # becomes
        # {"email":"john@example.com","name":"John"}
        arguments = json.loads(tool_call.function.arguments) # arguments suggested by LLM are stored in arguments
        print(f"Tool called: {tool_name}", flush=True) # prints the tool name  # Print which tool is being executed

        # THE BIG IF STATEMENT!!!

        if tool_name == "record_user_details": # if the tool name returned by LLM is record_user_details
            result = record_user_details(**arguments) # then run the record_user_details function with the arguments
        elif tool_name == "record_unknown_question": # if the tool name returned by LLM is record_unknown_question
            result = record_unknown_question(**arguments) # then run the record_unknown_question function with the arguments

        results.append({"role": "tool","content": json.dumps(result),"tool_call_id": tool_call.id})
    return results

   # Setting the role to "tool" tells the model, "This text is not a new user prompt; it is the raw output from the code execution you just requested."
    #tool call ID is a unique identifier string generated by an LLM when it decides to call an external function (or tool).

# Step 1: LLM requests a tool : The LLM might return something like:{
#   "function": {
#     "name": "record_user_details",
#     "arguments": "{\"email\":\"john@example.com\",\"name\":\"John\"}"
#   }
# }
# Step 2: Extract tool information : tool_name = "record_user_details"
# Step 3: Extract arguments : arguments = json.loads(tool_call.function.arguments)
# Step 4 :  Call the correct function : result = record_user_details(**arguments)
# Step 5: Store the result 

    # # LLM decides what tool to use
    # handle_tool_calls() executes the tool
    # The tool performs the action
    # Results are sent back to the LLM
    # LLM continues the conversation using those results

# %%
globals()["record_unknown_question"]("this is a really hard question")

# globals() is a built-in Python function that returns a dictionary containing all the global variables, functions, classes, and objects 
# currently defined in our program.
# Out:
# Push: Recording this is a really hard question asked that I couldn't answer
# {'recorded': 'ok'}

# %%
# This is a more elegant way that avoids the IF statement.

# Function that processes all tool calls returned by the LLM
def handle_tool_calls(tool_calls):

    # Create an empty list to store results from each tool execution
    results = []

    # Loop through each tool call suggested by the LLM
    for tool_call in tool_calls:

        # Extract the tool/function name
        # Example: "record_user_details"
        tool_name = tool_call.function.name

        # Convert the JSON string of arguments into a Python dictionary
        # Example:
        # '{"email":"john@example.com","name":"John"}'
        # becomes:
        # {"email":"john@example.com","name":"John"}
        arguments = json.loads(tool_call.function.arguments)

        # Print the name of the tool being executed
        # flush=True ensures it appears immediately in the console
        print(f"Tool called: {tool_name}", flush=True)

        # Look for a global function with the same name as tool_name
        # Example:
        # globals().get("record_user_details")
        # returns the actual function object:
        # <function record_user_details>
        tool = globals().get(tool_name)

        # If the function exists:
        #   tool(**arguments)
        #   calls the function with unpacked arguments
        #
        # Example:
        # arguments = {"email":"john@example.com","name":"John"}
        #
        # tool(**arguments)
        #
        # becomes:
        # record_user_details(
        #     email="john@example.com",
        #     name="John"
        # )
        #
        # If the function doesn't exist, return an empty dictionary
        result = tool(**arguments) if tool else {}

        # Add the tool result in the format expected by the OpenAI API
        results.append({

            # Indicates this message came from a tool
            "role": "tool",

            # Convert Python dictionary result into JSON string
            # Example:
            # {"recorded":"ok"}
            # becomes:
            # '{"recorded":"ok"}'
            "content": json.dumps(result),

            # Links this result back to the original tool call
            "tool_call_id": tool_call.id
        })

    # Return all tool results to be sent back to the LLM
    return results

# %%
# Create a reader object for the target PDF file (a CV document).
reader = PdfReader("me/Bhavisha_Tak_CV.pdf")

# Initialize an empty string variable to store all collected text.
linkedin = ""

# Loop through every page in the loaded PDF document.
for page in reader.pages:

    # Extract plain text content from the current page.
    text = page.extract_text()

    # Check if text was successfully extracted from the page.
    if text:
        # Append the extracted page text to our combined string variable.
        linkedin += text

name = "Bhavisha Tak"

# %%
# System prompt is different from user prompt as it has overall instructions that sets context for task at hand and 
# user prompt is actual question

system_prompt = f"""You are acting as {name}. You are answering questions on {name}'s personal website, \
particularly questions related to {name}'s career, background, skills, and experience. \
Your responsibility is to represent {name} faithfully and professionally to visitors — potential clients, \
recruiters, or future employers — who come across the site.

You will be given {name}'s CV/profile below. This is your ONLY source of truth about {name}.

Rules you must follow:
1. Answer questions using ONLY the information present in the profile provided below.
2. Never guess or invent details. If a question asks for something not covered in the profile \
(e.g. personal opinions, unlisted skills, salary expectations, availability, or anything not \
explicitly stated), you must NOT say "I don't have that information" or answer it directly — \
instead follow Rule 7 below (ask for their email first).
3. Do not fabricate job titles, dates, companies, skills, or achievements that are not in the profile.
4. Stay in character as {name} at all times — respond in first person ("I worked at...", "My experience includes...").
5. Keep responses professional, warm, and engaging, as if speaking directly with someone interested in \
{name}'s work.
6. If asked something completely unrelated to {name}'s career/background (e.g. general trivia, coding help \
for the visitor, etc.), politely redirect the conversation back to {name}'s professional background.
7. CRITICAL: If you cannot answer a question because the information is not in the profile, do NOT \
answer it, do NOT say "I don't have that information", and do NOT make excuses. Your VERY FIRST step \
MUST be to politely ask the visitor for their email address so {name} can follow up personally — do not \
call any tool on this turn. Once the visitor responds on their next message (with an email, or by \
declining), call record_unknown_question with the original question and their email (use 'not provided' \
if they decline or don't give one).
8. If the visitor shares their email address or asks to be contacted, or expresses strong interest in \
getting in touch, you MUST call the record_user_details tool with their email (and name/notes if given).

## Profile:
{linkedin}

With this context, please chat with the user, always staying in character as {name}.
"""

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    done = False
    while not done: # keep calling openai until done is true that is finish reason is not a tool call

        # This is the call to the LLM - see that we pass in the tools json
        # Here tools is structured json containing two functions and tell LLM these things you can do
        # response could be for user or may be tool LLM needs to use
        response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages, tools=tools)

        finish_reason = response.choices[0].finish_reason
        
        # If the LLM wants to call a tool, we do that!
        if finish_reason=="tool_calls":
            message = response.choices[0].message
            tool_calls = message.tool_calls
            results = handle_tool_calls(tool_calls) # call handle_tool_calls function to give LLM access of tool it asked for
            messages.append(message)
            messages.extend(results)
        else:
            done = True
    return response.choices[0].message.content

    # keep running a loop until finish reason is not a tool call

# %%
# Create a Gradio ChatInterface instance passing our custom 'chat' function, and launch the local web app UI.
gr.ChatInterface(chat).launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7864
# * Running on public URL: https://3c1facf311ade617bd.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://3c1facf311ade617bd.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Tool called: record_user_details
# Push: Recording interest from Name not provided with email bhav@gmail.com and notes not provided

# %% [markdown]
# # Deployment Guide: AI Chatbot to GitHub and Render
#
# This guide provides step-by-step instructions to structure, upload, and deploy your Gradio-based AI chatbot application on Render using GitHub.
#
# ---
#
# ## 1. Local Directory Structure
#
# Verify that your project root directory contains the following file organization:
#
# * `CHAT_BOT/`
#   * `me/`
#     * `Bhavisha_Tak_CV.pdf`
#   * `.gitignore`
#   * `app.py`
#   * `requirements.txt`
#
# ---
#
# ## 2. Configuration Files Setup
#
# ### Step A: Configure `requirements.txt`
# Ensure `requirements.txt` includes only the core dependencies needed to run the app:
#
# ```txt
# gradio
# openai
# pypdf
# requests
# python-dotenv
#
# ---

# %% [markdown]
# ## 3. GitHub Deployment
# Run these commands sequentially in your Cursor / VS Code terminal (Ctrl + ~):
# #### 1. Initialize Git repository
# git init
#
# #### 2. Stage all files and create initial commit
# git add .
# git commit -m "Initial commit: AI Chatbot app"
#
# ### 3. Rename default branch to main
# git branch -M main
#
# #### 4. Link your remote repository (replace with your repository URL)
# git remote add origin [https://github.com/YOUR_GITHUB_USERNAME/CHAT_BOT.git](https://github.com/YOUR_GITHUB_USERNAME/CHAT_BOT.git)
#
# #### 5. Push code to GitHub
# git push -u origin main
#
#
# ---

# %% [markdown]
# ## 4. Render Web Service Deployment
#
# 1. **Navigate to Render:**
#    Open the Render Dashboard at `https://dashboard.render.com`.
#
# 2. **Create New Service:**
#    Click **New +** and select **Web Service**.
#
# 3. **Connect Repository:**
#    Connect your GitHub account and select the `CHAT_BOT` repository.
#
# 4. **Set Build Configurations:**
#    * **Name:** `your_chat_bot_name`
#    * **Runtime:** `Python 3`
#    * **Branch:** `main`
#    * **Build Command:** `pip install -r requirements.txt`
#    * **Start Command:** `python app.py`
#    * **Instance Type:** `Free`
#
# 5. **Configure Environment Variables:**
#    Add the following required key-value pairs in the **Environment** section:
#    * `OPENAI_API_KEY`: Your OpenAI API secret key
#    * `TELEGRAM_BOT_TOKEN`: Token provided by `@BotFather`
#    * `TELEGRAM_CHAT_ID`: Numeric ID provided by `@userinfobot`
#
# 6. **Deploy Application:**
#    Click **Create Web Service** to launch the build process. Once complete, Render will generate a live URL for your app.
#
# ---
#
# ## 5. Verification Steps
#
# 1. Launch your live `.onrender.com` URL in a browser.
# 2. Submit a test question not covered in your PDF CV (e.g., *"What are your PhD plans?"*).
# 3. Provide a test email when requested by the model.
# 4. Confirm receipt of the lead notification in your Telegram application.

# %% [markdown]
# ## 4. Render Web Service Deployment
#
# 1. **Navigate to Render:**
#    Open the Render Dashboard at `https://dashboard.render.com`.
#
# 2. **Create New Service:**
#    Click **New +** and select **Web Service**.
#
# 3. **Connect Repository:**
#    Connect your GitHub account and select the `CHAT_BOT` repository.
#
# 4. **Set Build Configurations:**
#    * **Name:** `your_chat_bot_name`
#    * **Runtime:** `Python 3`
#    * **Branch:** `main`
#    * **Build Command:** `pip install -r requirements.txt`
#    * **Start Command:** `python app.py`
#    * **Instance Type:** `Free`
#
# 5. **Configure Environment Variables:**
#    Add the following required key-value pairs in the **Environment** section:
#    * `OPENAI_API_KEY`: Your OpenAI API secret key
#    * `TELEGRAM_BOT_TOKEN`: Token provided by `@BotFather`
#    * `TELEGRAM_CHAT_ID`: Numeric ID provided by `@userinfobot`
#
# 6. **Deploy Application:**
#    Click **Create Web Service** to launch the build process. Once complete, Render will generate a live URL for your app.
#
# ---
#
# ## 5. Verification Steps
#
# 1. Launch your live `.onrender.com` URL in a browser.
# 2. Submit a test question not covered in your PDF CV (e.g., *"What are your PhD plans?"*).
# 3. Provide a test email when requested by the model.
# 4. Confirm receipt of the lead notification in your Telegram application.
